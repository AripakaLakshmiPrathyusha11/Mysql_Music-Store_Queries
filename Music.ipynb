# %%
import pandas as pd
import numpy as np

# %%
df_album =pd.read_csv("album.csv")

# %%
df_album.head()
# Out:
#    album_id                                  title  artist_id
# 0         1  For Those About To Rock We Salute You          1
# 1         2                      Balls to the Wall          2
# 2         3                      Restless and Wild          2
# 3         4                      Let There Be Rock          1
# 4         5                               Big Ones          3

# %%
import re
album = r"a-zA-Z0-9"
df_album["title"] = df_album["title"].apply(lambda x: re.findall(album,str(x)))
df_album["title"] = df_album["title"].apply(lambda x: ''.join(x))
#df_album["title"] = df_album["title"].apply(lambda each_name :re.search(album, each_name))
#regex = r'[a-zA-Z0-9]'
#df['title'] = df['title'].apply(lambda x: re.findall(regex,str(x)))
#df['title'] = df['title'].apply(lambda x : ''.join(x))

# %%
df_album
# Out:
#      album_id title  artist_id
# 0           1                1
# 1           2                2
# 2           3                2
# 3           4                1
# 4           5                3
# ..        ...   ...        ...
# 342       343              226
# 343       344              272
# 344       345              273
# 345       346              274
# 346       347              275
#
# [347 rows x 3 columns]

# %%
df_album.reset

# %%
df_album.to_csv("album1.csv")

# %%
df_album
# Out:
#      album_id title  artist_id
# 0           1                1
# 1           2                2
# 2           3                2
# 3           4                1
# 4           5                3
# ..        ...   ...        ...
# 342       343              226
# 343       344              272
# 344       345              273
# 345       346              274
# 346       347              275
#
# [347 rows x 3 columns]

# %%
df_track = pd.read_csv("track.csv")

# %%
import re
track = r"a-zA-Z0-9"
df_track["name"] = df_track["name"].apply(lambda x: re.findall(track,str(x)))
df_track["name"] = df_track["name"].apply(lambda x: ''.join(x))

# %%
df_track
# Out:
#       track_id name  album_id  media_type_id  genre_id  \
# 0            1              1              1         1
# 1            2              2              2         1
# 2            3              3              2         1
# 3            4              3              2         1
# 4            5              3              2         1
# ...        ...  ...       ...            ...       ...
# 3498      3499            343              2        24
# 3499      3500            344              2        24
# 3500      3501            345              2        24
# 3501      3502            346              2        24
# 3502      3503            347              2        10
#
#                                                composer  milliseconds  \
# 0             Angus Young, Malcolm Young, Brian Johnson        343719
# 1                                                   NaN        342562
# 2     F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# ...

# %%
df_track.to_csv("track1.csv")
